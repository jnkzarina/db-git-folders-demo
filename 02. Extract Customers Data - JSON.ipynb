-- %%
%fs ls

-- %%
show catalogs;

-- %%
use catalog gizmobox;

-- %%
show catalogs

-- %%
create schema landing;

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/addresses

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/customers/

-- %%
select _metadata as file_path,* from json.`/Volumes/gizmobox/landing/operational_data/customers`;

-- %%
create or replace view gizmobox.bronze.v_customers as select _metadata.file_path as file_path,* from json.`/Volumes/gizmobox/landing/operational_data/customers`;

-- %%
select * from gizmobox.bronze.v_customers;

-- %%
create or replace temporary view tv_customers as select _metadata.file_path as file_path,* from json.`/Volumes/gizmobox/landing/operational_data/customers`;

-- %%
select * from tv_customers;

-- %%
create or replace global temporary view gtv_customers as select _metadata.file_path as file_path,* from json.`/Volumes/gizmobox/landing/operational_data/customers`;
