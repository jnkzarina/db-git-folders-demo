-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/payments/

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_payments as select * from read_files('/Volumes/gizmobox/landing/operational_data/payments/*.csv',
                        format => 'csv',
                        delimiter => ',',
                        header => false)

-- %%
-- CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
-- (payment_id integer, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING)
-- USING csv
-- OPTIONS (
--     header = "true",
--     delimiter = ","
-- )
-- LOCATION '/Volumes/gizmobox/landing/operational_data/payments';

SELECT * FROM gizmobox.bronze.v_payments;
